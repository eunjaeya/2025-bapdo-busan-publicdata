# %% [markdown]
# # 네이버지도 블로그 리뷰 수집

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
import time
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np

# %%
options = Options()
options.add_argument('--no-sandbox')
options.add_argument('--disable-dev-shm-usage')

driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)

place_name = '신창국밥 본점'
# 네이버 지도 검색 페이지
base_url = f'https://map.naver.com/p/search/{place_name}'
driver.get(base_url)
time.sleep(2)


# driver.switch_to.frame('searchIframe')
# time.sleep(1)
# driver.find_element(By.XPATH, '//*[@id="_pcmap_list_scroll_container"]/ul/li[1]/div[1]/div[2]/div[1]/a/span[1]').click()
# time.sleep(1)
# driver.switch_to.default_content()
# time.sleep(1)
driver.switch_to.frame('entryIframe')
# 댓글 버튼
# driver.find_element(By.XPATH, '//*[@id="app-root"]/div/div/div/div[4]/div/div/div/div/a[3]/span').click()
driver.find_element(By.XPATH, '//a[contains(text(), "리뷰")]').click()
time.sleep(1)
# 블로그 글
driver.find_element(By.XPATH, '//*[@id="_subtab_view"]/div/a[2]').click()
time.sleep(1)

# 최신순
try:
    driver.find_element(By.XPATH, '//*[@id="app-root"]/div/div/div/div[6]/div[3]/div/div[1]/div/div/div[1]/span[2]').click()
except:
    driver.find_element(By.XPATH, '//*[@id="app-root"]/div/div/div/div[6]/div[3]/div/div[1]/div/div/div[1]/span[2]').click()


for _ in range(10):
    # 맨 아래 스크롤
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(1)
    try:
        driver.find_element(By.XPATH, '//*[@id="app-root"]/div/div/div/div[6]/div[3]/div/div[2]/div/a/span').click()
    except:
        print("더보기 버튼이 없습니다.")
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
        break

html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')

df = pd.DataFrame(columns=['닉네임', '제목', '작성일', '리뷰'])
for content in soup.find_all('li', class_ = 'EblIP'):
    nickname = content.find('span', class_='pui__NMi-Dp').text
    title = content.find('div', class_='pui__dGLDWy').text
    date = content.find('time').text
    review = content.find('div', class_ = 'pui__vn15t2').find('span').text
    df.loc[len(df)] = [nickname, title, date, review]
df.to_csv(f'./data/리뷰/{place_name}_블로그리뷰.csv')
# Out:
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# Cell In[61], line 23
#      20 driver.switch_to.frame('entryIframe')
#      21 # 댓글 버튼
#      22 # driver.find_element(By.XPATH, '//*[@id="app-root"]/div/div/div/div[4]/div/div/div/div/a[3]/span').click()
# ---> 23 driver.find_element(By.XPATH, '//a[contains(text(), "리뷰")]').click()
#      24 time.sleep(1)
#      25 # 블로그 글
#
# File c:\Users\user\anaconda3\envs\py_397\lib\site-packages\selenium\webdriver\remote\webdriver.py:914, in WebDriver.find_element(self, by, value)
#     911         raise NoSuchElementException(f"Cannot locate relative element with: {by.root}")
#     912     return elements[0]
# --> 914 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File c:\Users\user\anaconda3\envs\py_397\lib\site-packages\selenium\webdriver\remote\webdriver.py:447, in WebDriver.execute(self, driver_command, params)
#     445 response = self.command_executor.execute(driver_command, params)
#     446 if response:
# --> 447     self.error_handler.check_response(response)
#     448     response["value"] = self._unwrap_value(response.get("value", None))
#     449     return response
#
# File c:\Users\user\anaconda3\envs\py_397\lib\site-packages\selenium\webdriver\remote\errorhandler.py:232, in ErrorHandler.check_response(self, response)
#     230         alert_text = value["alert"].get("text")
#     231     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 232 raise exception_class(message, screen, stacktrace)
#
# NoSuchWindowException: Message: no such window: target window already closed
# from unknown error: web view not found
#   (Session info: chrome=137.0.7151.104)
# Stacktrace:
# 	GetHandleVerifier [0x0x323783+63299]
# 	GetHandleVerifier [0x0x3237c4+63364]
# 	(No symbol) [0x0x151113]
# 	(No symbol) [0x0x12ff69]
# 	(No symbol) [0x0x1c4fce]
# 	(No symbol) [0x0x1df359]
# 	(No symbol) [0x0x1be376]
# 	(No symbol) [0x0x18d6e0]
# 	(No symbol) [0x0x18e544]
# 	GetHandleVerifier [0x0x57e073+2531379]
# 	GetHandleVerifier [0x0x579372+2511666]
# 	GetHandleVerifier [0x0x349efa+220858]
# 	GetHandleVerifier [0x0x33a548+156936]
# 	GetHandleVerifier [0x0x340c7d+183357]
# 	GetHandleVerifier [0x0x32b6e8+95912]
# 	GetHandleVerifier [0x0x32b890+96336]
# 	GetHandleVerifier [0x0x31666a+9770]
# 	BaseThreadInitThunk [0x0x753d5d49+25]
# 	RtlInitializeExceptionChain [0x0x771bd09b+107]
# 	RtlGetAppContainerNamedObjectPath [0x0x771bd021+561]
# 	(No symbol) [0x0]

# %% [markdown]
# ## 함수 + 반복문

# %%
def collect_blog_reviews(place_name):
    options = Options()
    options.add_argument('--no-sandbox')
    options.add_argument('--disable-dev-shm-usage')

    driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)
    # 네이버 지도 검색 페이지
    base_url = f'https://map.naver.com/p/search/{place_name}'
    driver.get(base_url)
    time.sleep(2)

    # driver.switch_to.frame('searchIframe')
    # time.sleep(1)
    # driver.find_element(By.XPATH, '//*[@id="_pcmap_list_scroll_container"]/ul/li[1]/div[1]/div[2]/div[1]/a/span[1]').click()
    # time.sleep(1)
    # driver.switch_to.default_content()
    # time.sleep(1)
    driver.switch_to.frame('entryIframe')
    # 댓글 버튼
    #driver.find_element(By.XPATH, '//*[@id="app-root"]/div/div/div/div[4]/div/div/div/div/a[3]/span').click()
    driver.find_element(By.XPATH, '//a[contains(text(), "리뷰")]').click()
    time.sleep(1)
    # 블로그 글
    driver.find_element(By.XPATH, '//*[@id="_subtab_view"]/div/a[2]').click()
    time.sleep(2)

    # 최신순
    try:
        driver.find_element(By.XPATH, '//*[@id="app-root"]/div/div/div/div[6]/div[3]/div/div[1]/div/div/div[1]/span[2]').click()
    except:
        driver.find_element(By.XPATH, '//*[@id="app-root"]/div/div/div/div[6]/div[3]/div/div[1]/div/div/div[1]/span[2]').click()

    for _ in range(20):
        # 맨 아래 스크롤
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
        time.sleep(1)
        try:
            driver.find_element(By.XPATH, '//*[@id="app-root"]/div/div/div/div[6]/div[3]/div/div[2]/div/a/span').click()
        except:
            print("더보기 버튼이 없습니다.")
            driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
            break

    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')

    df = pd.DataFrame(columns=['닉네임', '제목', '작성일', '리뷰'])
    for content in soup.find_all('li', class_ = 'EblIP'):
        nickname = content.find('span', class_='pui__NMi-Dp').text
        title = content.find('div', class_='pui__dGLDWy').text
        date = content.find('time').text
        review = content.find('div', class_ = 'pui__vn15t2').find('span').text
        df.loc[len(df)] = [nickname, title, date, review]
    time.sleep(1)
    driver.quit()
    return df

# %% [markdown]
# ### 수집대상 불러오기

# %%
famous_df = pd.read_csv('./data/유명가게.csv')
famous_df.drop(index=[14, 15, 39], inplace=True)
famous_df.reset_index(inplace=True, drop=True)
famous_df.head()
# Out:
#                   식당명                    주소
# 0            합천일류돼지국밥            사상구 광장로 34
# 1             신창국밥 본점            서구 보수대로 53
# 2          쌍둥이돼지국밥 본점         남구 유엔평화로 35-1
# 3         60년 전통 할매국밥        동구 중앙대로533번길 4
# 4  몽실종가돼지국밥 감천문화마을 본점  서구 까치고개로 197번길 3, 1층

# %%
famous_df['수집여부'] = np.nan

for i in range(len(famous_df)):
    name = famous_df.loc[i].values[0]
    place_name = famous_df.loc[i].values[0] + ' ' + famous_df.loc[i].values[1]
    print(i, name, '수집시작')
    try:
        df = collect_blog_reviews(place_name)
        df.to_csv(f'./data/리뷰/{name}_블로그리뷰.csv', index=False)
        famous_df.loc[i ,'수집여부'] = True
        print('수집성공')
    except:
        try:
            df = collect_blog_reviews(name)
            df.to_csv(f'./data/리뷰/{name}_블로그리뷰.csv', index=False)
            famous_df.loc[i ,'수집여부'] = True
            print('수집성공')
        except:
            famous_df.loc[i ,'수집여부'] = False
            print('수집실패')
# Out:
# 0 합천일류돼지국밥 수집시작
# 더보기 버튼이 없습니다.
# C:\Users\user\AppData\Local\Temp\ipykernel_25664\981189937.py:10: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'True' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   famous_df.loc[i ,'수집여부'] = True
# 수집성공
# 1 신창국밥 본점 수집시작
# 더보기 버튼이 없습니다.
# 수집성공
# 2 쌍둥이돼지국밥 본점 수집시작
# 더보기 버튼이 없습니다.
# 수집성공
# 3 60년 전통 할매국밥 수집시작
# 더보기 버튼이 없습니다.
# 수집성공
# 4 몽실종가돼지국밥 감천문화마을 본점 수집시작
# 더보기 버튼이 없습니다.
# 수집성공
# 5 영진돼지국밥 본점 수집시작
# 더보기 버튼이 없습니다.
# 수집성공
# 6 합천국밥집 수집시작
# 더보기 버튼이 없습니다.
# 수집성공
# 7 정짓간 돼지국밥 & 막국수 수집시작
# 더보기 버튼이 없습니다.
# 수집성공
# 8 우리돼지국밥 수집시작
# 더보기 버튼이 없습니다.
# 수집성공
# 9 수복돼지국밥 수집시작
# 수집실패
# 10 부광돼지국밥전문점 수집시작
# 더보기 버튼이 없습니다.
# 수집성공
# 11 두번째 늘해랑 수집시작
# 더보기 버튼이 없습니다.
# 수집성공
# 12 재기돼지국밥 수집시작
# 더보기 버튼이 없습니다.
# 수집성공
# 13 자매국밥 수집시작
# 더보기 버튼이 없습니다.
# 수집성공
# 14 송정3대국밥 수집시작
# 더보기 버튼이 없습니다.
# 수집성공
# 15 원산순대돼지국밥 수집시작
# 더보기 버튼이 없습니다.
# 수집성공
# 16 오가네국밥 수집시작
# 더보기 버튼이 없습니다.
# 수집성공
# 17 바보국밥1호점 수집시작
# 더보기 버튼이 없습니다.
# 수집성공
# 18 세화돼지국밥 수집시작
# 더보기 버튼이 없습니다.
# 수집성공
# 19 수라국밥 수집시작
# 더보기 버튼이 없습니다.
# 수집성공
# 20 영진돼지국밥 수집시작
# 수집실패
# 21 마루돼지국밥 수집시작
# 수집실패
# 22 장수돼지국밥 수집시작
# 더보기 버튼이 없습니다.
# 수집성공
# 23 더도이종가집돼지국밥 수집시작
# 수집실패
# 24 합천돼지국밥 수집시작
# 더보기 버튼이 없습니다.
# 수집성공
# 25 아제돼지국밥 수집시작
# 수집실패
# 26 경주박가국밥 수집시작
# 더보기 버튼이 없습니다.
# 수집성공
# 27 굴마을굴국밥 수집시작
# 수집실패
# 28 병천순대국밥 수집시작
# 더보기 버튼이 없습니다.
# 수집성공
# 29 또랑돼지국밥 수집시작
# 수집실패
# 30 밀양삼대국밥 수집시작
# 더보기 버튼이 없습니다.
# 수집성공
# 31 시장국밥집 수집시작
# 수집실패
# 32 가야포차선지국밥 수집시작
# 수집실패
# 33 백양돼지국밥 수집시작
# 수집실패
# 34 장수국밥 수집시작
# 더보기 버튼이 없습니다.
# 수집성공
# 35 신창국밥 수집시작
# 수집실패
# 36 교통부돼지국밥 수집시작
# 수집실패
# 37 재민국밥 수집시작
# 더보기 버튼이 없습니다.
# 수집성공
# 38 초량돼지국밥 수집시작
# 더보기 버튼이 없습니다.
# 수집성공
# 39 사천돼지국밥 수집시작
# 더보기 버튼이 없습니다.
# 수집성공
# 40 연창돼지국밥 수집시작
# 더보기 버튼이 없습니다.
# 수집성공
# 41 하동돼지국밥 수집시작
# 수집실패
# 42 정아밀면돼지국밥 수집시작
# 더보기 버튼이 없습니다.
# 수집성공
# 43 뿅가네장수돼지국밥 수집시작
# 수집실패
# 44 부원돼지국밥 수집시작
# 수집실패
# 45 터줏집돼지국밥 수집시작
# 더보기 버튼이 없습니다.
# 수집성공
# 46 장미돼지국밥 수집시작
# 수집실패
# 47 이가네돼지국밥 수집시작
# 수집실패
# 48 명지돼지국밥 수집시작
# 수집실패
# 49 경주전통돼지국밥 수집시작
# 수집실패
# 50 돌고래돼지국밥 수집시작
# 더보기 버튼이 없습니다.
# 수집성공
# 51 장원돼지국밥 수집시작
# 수집실패
# 52 형제돼지국밥 수집시작
# 수집실패
# 53 수백한상 수집시작
# 더보기 버튼이 없습니다.
# 수집성공
# 54 남해돼지국밥 수집시작
# 수집실패
# 55 시골돼지국밥 수집시작
# 수집실패
# 56 시골돼지국밥 수집시작
# 더보기 버튼이 없습니다.
# 수집성공

# %%
famous_df.to_csv('./data/유명가게_수집현황.csv', index=False)

# %%
total_df = pd.read_csv('./data/전체가게.csv', index_col= 0)
total_df
# Out:
#            식당명                                  주소
# 0       설봉돼지국밥           부산광역시 금정구 수림로49번길 6 (장전동)
# 1      또순이돼지국밥               부산광역시 금정구 서부로 20 (서동)
# 2   목촌돼지국밥 서동점              부산광역시 금정구 서동로 192 (서동)
# 3       영진돼지국밥              부산광역시 금정구 개좌로 84 (금사동)
# 4       장수돼지국밥              부산광역시 금정구 부곡로 96 (부곡동)
# ..         ...                                 ...
# 88    필순할매돼지국밥      부산광역시 부산진구 새싹로8번길 16, 1층 (부전동)
# 89      참잘돼지국밥  부산광역시 부산진구 서전로 11-1, 신전빌딩 1층 (부전동)
# 90     다복 돼지국밥        부산광역시 부산진구 냉정로 204, 1층 (개금동)
# 91   최고집명가돼지국밥     부산광역시 부산진구 중앙대로 903-1, 1층 (양정동)
# 92      흥부돼지국밥   부산광역시 부산진구 전포대로200번길 24, 1층 (전포동)
#
# [93 rows x 2 columns]

# %%
total_df['수집여부'] = np.nan

for i in range(len(total_df)):
    name = total_df.loc[i].values[0]
    place_name = total_df.loc[i].values[0] + ' ' + total_df.loc[i].values[1]
    print(i, name, '수집시작')
    try:
        df = collect_blog_reviews(place_name)
        df.to_csv(f'./data/전체가게_리뷰/{name}_블로그리뷰.csv', index=False)
        total_df.loc[i ,'수집여부'] = True
        print('수집성공')
    except:
        try:
            df = collect_blog_reviews(name)
            df.to_csv(f'./data/전체가게_리뷰/{name}_블로그리뷰.csv', index=False)
            total_df.loc[i ,'수집여부'] = True
            print('수집성공')
        except:
            total_df.loc[i ,'수집여부'] = False
            print('수집실패')
# Out:
# 0 설봉돼지국밥 수집시작
# 더보기 버튼이 없습니다.
# C:\Users\user\AppData\Local\Temp\ipykernel_23804\1741578435.py:10: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'True' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   total_df.loc[i ,'수집여부'] = True
# 수집성공
# 1 또순이돼지국밥 수집시작
# 더보기 버튼이 없습니다.
# 수집성공
# 2 목촌돼지국밥 서동점 수집시작
# 더보기 버튼이 없습니다.
# 수집성공
# 3 영진돼지국밥 수집시작
# 더보기 버튼이 없습니다.
# 수집성공
# 4 장수돼지국밥 수집시작
# 수집실패
# 5 별미청 돼지국밥 수집시작
# 더보기 버튼이 없습니다.
# 수집성공
# 6 행복돼지국밥 수집시작
# 더보기 버튼이 없습니다.
# 수집성공
# 7 장수돼지국밥 수집시작
# 더보기 버튼이 없습니다.
# 수집성공
# 8 남산돼지국밥 수집시작
# 수집실패
# 9 언양돼지국밥 수집시작
# 더보기 버튼이 없습니다.
# 수집성공
# 10 소문난돼지국밥 수집시작
# 수집실패
# 11 마루돼지국밥 수집시작
# 더보기 버튼이 없습니다.
# 수집성공
# 12 금문돼지국밥 수집시작
# 더보기 버튼이 없습니다.
# 수집성공
# 13 우리마을돼지국밥 수집시작
# 더보기 버튼이 없습니다.
# 수집성공
# 14 무진장돼지국밥 수집시작
# 수집실패
# 15 수라돼지국밥 수집시작
# 더보기 버튼이 없습니다.
# 수집성공
# 16 장수원돼지국밥 수집시작
# 더보기 버튼이 없습니다.
# 수집성공
# 17 화로돼지국밥 수집시작
# 더보기 버튼이 없습니다.
# 수집성공
# 18 밀양돼지국밥 수집시작
# 수집실패
# 19 서동돼지국밥 수집시작
# 수집실패
# 20 정원돼지국밥 수집시작
# 수집실패
# 21 가야공원돼지국밥 수집시작
# 더보기 버튼이 없습니다.
# 수집성공
# 22 미광돼지국밥 수집시작
# 더보기 버튼이 없습니다.
# 수집성공
# 23 합천돼지국밥 수집시작
# 수집실패
# 24 왕대박돼지국밥 수집시작
# 더보기 버튼이 없습니다.
# 수집성공
# 25 현대보쌈돼지국밥 수집시작
# 더보기 버튼이 없습니다.
# 수집성공
# 26 금정돼지국밥 수집시작
# 수집실패
# 27 복돈돼지국밥 수집시작
# 수집실패
# 28 고려돼지국밥 수집시작
# 수집실패
# 29 한성 가마솥 돼지국밥 수집시작
# 더보기 버튼이 없습니다.
# 수집성공
# 30 장전돼지국밥 수집시작
# 수집실패
# 31 백년 돼지국밥 수집시작
# 수집실패
# 32 한뚝배기 돼지국밥 수집시작
# 수집실패
# 33 밀양돼지국밥&감자탕 수집시작
# 수집실패
# 34 구월산 돼지국밥 수집시작
# 수집실패
# 35 청화백 돼지국밥 수집시작
# 수집실패
# 36 서면포항돼지국밥 수집시작
# 더보기 버튼이 없습니다.
# 수집성공
# 37 부산돼지국밥 수집시작
# 더보기 버튼이 없습니다.
# 수집성공
# 38 큰집돼지국밥 수집시작
# 더보기 버튼이 없습니다.
# 수집성공
# 39 돼지국밥집 수집시작
# 수집실패
# 40 장터돼지국밥 수집시작
# 수집실패
# 41 한방돼지국밥 수집시작
# 더보기 버튼이 없습니다.
# 수집성공
# 42 장수 돼지국밥 수집시작
# 더보기 버튼이 없습니다.
# 수집성공
# 43 수영본가돼지국밥 수집시작
# 더보기 버튼이 없습니다.
# 수집성공
# 44 중앙돼지국밥 수집시작
# 수집실패
# 45 본동개금돼지국밥 수집시작
# 더보기 버튼이 없습니다.
# 수집성공
# 46 가야돼지국밥 수집시작
# 더보기 버튼이 없습니다.
# 수집성공
# 47 시골돼지국밥 수집시작
# 더보기 버튼이 없습니다.
# 수집성공
# 48 합천돼지국밥 수집시작
# 수집실패
# 49 당감동 돼지국밥 수집시작
# 수집실패
# 50 수영공원돼지국밥(분점) 수집시작
# 수집실패
# 51 선정문 돼지국밥 수집시작
# 더보기 버튼이 없습니다.
# 수집성공
# 52 일품장원돼지국밥 수집시작
# 더보기 버튼이 없습니다.
# 수집성공
# 53 원조가야돼지국밥 수집시작
# 더보기 버튼이 없습니다.
# 수집성공
# 54 합천돼지국밥 수집시작
# 더보기 버튼이 없습니다.
# 수집성공
# 55 백양돼지국밥 수집시작
# 수집실패
# 56 늘찬돼지국밥 수집시작
# 더보기 버튼이 없습니다.
# 수집성공
# 57 두루와 돼지국밥 수집시작
# 수집실패
# 58 정가네합천돼지국밥 수집시작
# 수집실패
# 59 영진돼지국밥 수집시작
# 더보기 버튼이 없습니다.
# 수집성공
# 60 조방돼지국밥 수집시작
# 더보기 버튼이 없습니다.
# 수집성공
# 61 이가네부산돼지국밥·밀면 수집시작
# 수집실패
# 62 청도돼지국밥 수집시작
# 수집실패
# 63 가야공원돼지국밥 수집시작
# 수집실패
# 64 영진돼지국밥 수집시작
# 수집실패
# 65 풍성돼지국밥 수집시작
# 더보기 버튼이 없습니다.
# 수집성공
# 66 화남정돼지국밥 수집시작
# 수집실패
# 67 산청 돼지국밥 수집시작
# 수집실패
# 68 초읍공원돼지국밥 수집시작
# 더보기 버튼이 없습니다.
# 수집성공
# 69 나주돼지국밥 수집시작
# 수집실패
# 70 부산돼지국밥 수집시작
# 수집실패
# 71 교통부돼지국밥 수집시작
# 수집실패
# 72 부자돼지국밥 수집시작
# 수집실패
# 73 부자돼지국밥 수집시작
# 수집실패
# 74 (주)행복만들기 밀양순대돼지국밥 서면점 수집시작
# 수집실패
# 75 수영공원돼지국밥 수집시작
# 수집실패
# 76 소문난돼지국밥 수집시작
# 수집실패
# 77 진짜소문난돼지국밥 수집시작
# 더보기 버튼이 없습니다.
# 수집성공
# 78 제일돼지국밥 수집시작
# 수집실패
# 79 진주돼지국밥 수집시작
# 수집실패
# 80 소문난장터돼지국밥 수집시작
# 수집실패
# 81 본토돼지국밥 수집시작
# 수집실패
# 82 착한진돼지국밥 수집시작
# 더보기 버튼이 없습니다.
# 수집성공
# 83 연돼지국밥 수집시작
# 수집실패
# 84 일타돼지국밥 수집시작
# 더보기 버튼이 없습니다.
# 수집성공
# 85 최고쌍둥이돼지국밥 수집시작
# 더보기 버튼이 없습니다.
# 수집성공
# 86 갈맷길돼지국밥 수집시작
# 수집실패
# 87 소문난장터돼지국밥2호점 수집시작
# 수집실패
# 88 필순할매돼지국밥 수집시작
# 수집실패
# 89 참잘돼지국밥 수집시작
# 수집실패
# 90 다복 돼지국밥 수집시작
# 수집실패
# 91 최고집명가돼지국밥 수집시작
# 더보기 버튼이 없습니다.
# 수집성공
# 92 흥부돼지국밥 수집시작
# 수집실패

# %%
total_df.to_csv('./data/전체가게_수집현황.csv', index=False)

# %% [markdown]
# # 수집 실패 처리

# %%
famous_df = pd.read_csv('./data/유명가게_수집현황.csv')

# %%
def collect_blog_reviews_address(address):
    options = Options()
    options.add_argument('--no-sandbox')
    options.add_argument('--disable-dev-shm-usage')

    driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)
    # 네이버 지도 검색 페이지
    base_url = f'https://map.naver.com/p/search/{address}'
    driver.get(base_url)
    time.sleep(2)

    try:
        driver.find_element(By.XPATH, '//*[@id="sub_panel"]/div/div[1]/div/div/div/div/div[1]/div[3]/div[2]/ul/li/button').click()
    except:
        pass
    time.sleep(2)
    driver.switch_to.frame('entryIframe')
    # 댓글 버튼
    #driver.find_element(By.XPATH, '//*[@id="app-root"]/div/div/div/div[4]/div/div/div/div/a[3]/span').click()
    driver.find_element(By.XPATH, '//a[contains(text(), "리뷰")]').click()
    time.sleep(1)
    # 블로그 글
    driver.find_element(By.XPATH, '//*[@id="_subtab_view"]/div/a[2]').click()
    time.sleep(3)

    # 최신순
    try:
        driver.find_element(By.XPATH, '//*[@id="app-root"]/div/div/div/div[6]/div[3]/div/div[1]/div/div/div[1]/span[2]').click()
        time.sleep(3)
    except:
        driver.find_element(By.XPATH, '//*[@id="app-root"]/div/div/div/div[6]/div[3]/div/div[1]/div/div/div[1]/span[2]').click()

    for _ in range(20):
        # 맨 아래 스크롤
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
        time.sleep(1)
        try:
            driver.find_element(By.XPATH, '//*[@id="app-root"]/div/div/div/div[6]/div[3]/div/div[2]/div/a/span').click()
        except:
            print("더보기 버튼이 없습니다.")
            driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
            break

    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')

    df = pd.DataFrame(columns=['닉네임', '제목', '작성일', '리뷰'])
    for content in soup.find_all('li', class_ = 'EblIP'):
        nickname = content.find('span', class_='pui__NMi-Dp').text
        title = content.find('div', class_='pui__dGLDWy').text
        date = content.find('time').text
        review = content.find('div', class_ = 'pui__vn15t2').find('span').text
        df.loc[len(df)] = [nickname, title, date, review]
    time.sleep(1)
    driver.quit()
    return df

# %%
famous_df = famous_df.drop(index=37)
famous_df.reset_index(drop=True, inplace=True)
famous_df.to_csv('./data/유명가게_수집현황.csv', index=False)

# %%
famous_df = pd.read_csv('./data/유명가게_수집현황.csv')
famous_df
# Out:
#                    식당명                                         주소   수집여부
# 0             합천일류돼지국밥                                 사상구 광장로 34   True
# 1              신창국밥 본점                                 서구 보수대로 53   True
# 2           쌍둥이돼지국밥 본점                              남구 유엔평화로 35-1   True
# 3          60년 전통 할매국밥                             동구 중앙대로533번길 4   True
# 4   몽실종가돼지국밥 감천문화마을 본점                       서구 까치고개로 197번길 3, 1층   True
# 5            영진돼지국밥 본점                          사하구 하신번영로157번길 39   True
# 6                합천국밥집                                 남구 용호로 235   True
# 7       정짓간 돼지국밥 & 막국수                               사하구 비봉로 6 1층   True
# 8               우리돼지국밥                                동구 초량로 27-1   True
# 9               수복돼지국밥                            연제구 고분로 41-1 2층   True
# 10           부광돼지국밥전문점                          중구 대청로 141번길 15-1   True
# 11             두번째 늘해랑                            부산진구 양지로 5번길 24   True
# 12              재기돼지국밥                            영도구 절영로 49번길 25   True
# 13                자매국밥                           수영구 민락본동로27번길 56   True
# 14              송정3대국밥                         부산 부산진구 서면로68번길 33   True
# 15            원산순대돼지국밥                      부산광역시 기장군 기장읍 차성남로 58   True
# 16               오가네국밥                   부산광역시 기장군 기장읍 차성로334번길 5   True
# 17             바보국밥1호점               부산광역시 기장군 기장읍 차성로344번길 32 1층   True
# 18              세화돼지국밥                        부산광역시 남구 고동골로78번길67   True
# 19                수라국밥                          부산광역시 남구 용소로8번길21   True
# 20              영진돼지국밥                      부산광역시 강서구 명지오션시티8로 31   True
# 21              마루돼지국밥                        부산광역시 금정구 개좌로 59-12   True
# 22              장수돼지국밥                      부산광역시 금정구 금정로237번길 12   True
# 23              합천돼지국밥                           부산광역시 금정구 서금로 17   True
# 24              경주박가국밥                      부산광역시 동래구 사직북로13번길 12   True
# 25              병천순대국밥                          부산광역시 동래구 안연로 109   True
# 26              또랑돼지국밥                     부산광역시 동래구 충렬대로359번길 12   True
# 27              밀양삼대국밥                     부산광역시 동래구 충렬대로359번길 23   True
# 28              백양돼지국밥                     부산광역시 부산진구 백양관문로 84 3층   True
# 29                장수국밥                       부산광역시 부산진구 새싹로29번길 8   True
# 30             교통부돼지국밥                     부산광역시 부산진구 연지로 12-1 1층   True
# 31                재민국밥                       부산광역시 동래구 명륜로98번길 66   True
# 32              초량돼지국밥                       부산 동구 중앙대로214번길 3-12   True
# 33              사천돼지국밥            부산 수영구 수영성로 20 부산 수영구 수영동 142-1   True
# 34              연창돼지국밥                           부산광역시 영도구 중리북로 8   True
# 35              하동돼지국밥                              부산 북구 만덕대로 68  False
# 36            정아밀면돼지국밥                      부산광역시 동구 중앙대로251번길 18   True
# 37              부원돼지국밥                       부산광역시 동래구 여고로91번길 90   True
# 38             터줏집돼지국밥                     부산광역시 금정구 부산대학로49번길 13   True
# 39              장미돼지국밥  부산 사하구 오작로8번안길 7 부산 사하구 괴정동 450-1 , B101호  False
# 40             이가네돼지국밥                      부산시 기장군 기장읍 읍내로 103-1   True
# 41              명지돼지국밥                     부산시 강서구 명지오션시티8로6번길 13  False
# 42            경주전통돼지국밥                          부산시 북구 만덕2로44번길43   True
# 43             돌고래돼지국밥                          부산시 남구 용소로 21번길 3   True
# 44              장원돼지국밥                           부산시 동구 고관로 129-1   True
# 45              형제돼지국밥                      부산광역시 남구 용소로13번길 29-1  False
# 46                수백한상                       부산광역시 해운대구 구남로8번길 86   True
# 47              남해돼지국밥                        부산광역시 해운대구 선수촌로 184   True
# 48              시골돼지국밥                            부산시 남구 석포로20번길4   True
# 49              시골돼지국밥                       부산광역시 사하구 괴정로43번길 23   True

# %%
famous_df.to_csv('./data/유명가게_수집현황.csv', index=False)

# %%
for i in range(len(famous_df)):
    if famous_df.loc[i, '수집여부'] == False:
        name = famous_df.loc[i].values[0]
        address = famous_df.loc[i].values[1]
        print(i, name, '수집시작')
        try:
            df = collect_blog_reviews_address(address)
            df.to_csv(f'./data/유명가게_리뷰/{name}_블로그리뷰.csv', index=False)
            famous_df.loc[i ,'수집여부'] = True
            print('수집성공')
        except Exception as e:
            print("오류 발생:", e)
            print()
            famous_df.loc[i ,'수집여부'] = False
            print('수집실패')
# Out:
# 35 하동돼지국밥 수집시작
# 더보기 버튼이 없습니다.
# 수집성공

# %%
total_df = pd.read_csv('./data/전체가게_수집현황.csv')

# %%
total_df[total_df['수집여부'] == False]
# Out:
#                       식당명                                        주소   수집여부
# 7                  남산돼지국밥                       부산광역시 금정구 중앙대로 2023  False
# 9                 소문난돼지국밥                         부산광역시 금정구 금사로 171  False
# 13                무진장돼지국밥                   부산광역시 금정구 중앙대로1531번길 12  False
# 18                 서동돼지국밥                       부산광역시 금정구 서동로 130-1  False
# 19                 정원돼지국밥                   부산광역시 금정구 중앙대로1685번길 31  False
# 25                 복돈돼지국밥                 부산광역시 금정구 범어천로52번길 31, 1층  False
# 28                 장전돼지국밥                    부산광역시 금정구 부산대학로49번길 13  False
# 29                백년 돼지국밥                      부산광역시 금정구 개좌로 17, 1층  False
# 30              한뚝배기 돼지국밥                       부산광역시 금정구 서명로 9, 1층  False
# 31             밀양돼지국밥&감자탕                부산광역시 금정구 중앙대로1959번길 8, 1층  False
# 32               구월산 돼지국밥                      부산광역시 금정구 장전로 14, 1층  False
# 37                  돼지국밥집                  부산광역시 부산진구 동천로132번길 23-1  False
# 38                 장터돼지국밥                 부산광역시 부산진구 가야대로 590-2, 1층  False
# 48           수영공원돼지국밥(분점)                        부산광역시 부산진구 엄광로 128  False
# 55              정가네합천돼지국밥                     부산광역시 부산진구 연수로11번길 57  False
# 58           이가네부산돼지국밥·밀면                부산광역시 부산진구 신천대로50번길 66, 1층  False
# 59                 청도돼지국밥                        부산광역시 부산진구 새싹로 209  False
# 64                산청 돼지국밥    부산광역시 부산진구 진사로61번길 29, 제15동 지하1층 2호,3호  False
# 66                 나주돼지국밥                  부산광역시 부산진구 가야대로765번길 8 )  False
# 67                 부산돼지국밥                   부산광역시 부산진구 새싹로 84, 지하1층  False
# 68                교통부돼지국밥                     부산광역시 부산진구 연지로 12-1 )  False
# 70                 부자돼지국밥                    부산광역시 부산진구 냉정로 234, 1층  False
# 71  (주)행복만들기 밀양순대돼지국밥 서면점              부산광역시 부산진구 신천대로50번길 65, 지상1층  False
# 72               수영공원돼지국밥                 부산광역시 부산진구 가야공원로 59, 1,2층  False
# 75                 제일돼지국밥  부산광역시 부산진구 당감로 108, 협성피닉스타운 112동 1층 105호  False
# 83                갈맷길돼지국밥                    부산광역시 부산진구 동평로 203, 1층  False
# 84           소문난장터돼지국밥2호점                 부산광역시 부산진구 동성로96번길 10, 1층  False
# 85               필순할매돼지국밥                  부산광역시 부산진구 새싹로8번길 16, 1층  False
# 86                 참잘돼지국밥              부산광역시 부산진구 서전로 11-1, 신전빌딩 1층  False

# %%
total_df.to_csv('./data/전체가게_수집현황.csv', index=False)

# %%
for i in range(len(total_df)):
    if total_df.loc[i, '수집여부'] == False:
        name = total_df.loc[i].values[0]
        address = total_df.loc[i].values[1]
        search = name + ' ' + address
        print(i, name, '수집시작')
        try:
            df = collect_blog_reviews_address(search)
            df.to_csv(f'./data/전체가게_리뷰/{name}_블로그리뷰.csv', index=False)
            total_df.loc[i ,'수집여부'] = True
            print('수집성공')
        except Exception as e:
            print("오류 발생:", e)
            print()
            total_df.loc[i ,'수집여부'] = False
            print('수집실패')
# Out:
# 7 남산돼지국밥 수집시작
# 오류 발생: Message: entryIframe
#
#
# 수집실패
# 9 소문난돼지국밥 수집시작
# 오류 발생: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="_subtab_view"]/div/a[2]"}
#   (Session info: chrome=137.0.7151.104); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x0x323783+63299]
# 	GetHandleVerifier [0x0x3237c4+63364]
# 	(No symbol) [0x0x151113]
# 	(No symbol) [0x0x19987e]
# 	(No symbol) [0x0x199c1b]
# 	(No symbol) [0x0x1e2212]
# 	(No symbol) [0x0x1be5c4]
# 	(No symbol) [0x0x1dfa4a]
# 	(No symbol) [0x0x1be376]
# 	(No symbol) [0x0x18d6e0]
# 	(No symbol) [0x0x18e544]
# 	GetHandleVerifier [0x0x57e073+2531379]
# 	GetHandleVerifier [0x0x579372+2511666]
# 	GetHandleVerifier [0x0x349efa+220858]
# 	GetHandleVerifier [0x0x33a548+156936]
# 	GetHandleVerifier [0x0x340c7d+183357]
# 	GetHandleVerifier [0x0x32b6e8+95912]
# 	GetHandleVerifier [0x0x32b890+96336]
# 	GetHandleVerifier [0x0x31666a+9770]
# 	BaseThreadInitThunk [0x0x753d5d49+25]
# 	RtlInitializeExceptionChain [0x0x771bd09b+107]
# 	RtlGetAppContainerNamedObjectPath [0x0x771bd021+561]
# 	(No symbol) [0x0]
#
#
# 수집실패
# 13 무진장돼지국밥 수집시작
# 오류 발생: Message: entryIframe
#
#
# 수집실패
# 18 서동돼지국밥 수집시작
# 오류 발생: Message: entryIframe
#
#
# 수집실패
# 19 정원돼지국밥 수집시작
# 오류 발생: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="_subtab_view"]/div/a[2]"}
#   (Session info: chrome=137.0.7151.104); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x0x323783+63299]
# 	GetHandleVerifier [0x0x3237c4+63364]
# 	(No symbol) [0x0x151113]
# 	(No symbol) [0x0x19987e]
# 	(No symbol) [0x0x199c1b]
# 	(No symbol) [0x0x1e2212]
# 	(No symbol) [0x0x1be5c4]
# 	(No symbol) [0x0x1dfa4a]
# 	(No symbol) [0x0x1be376]
# 	(No symbol) [0x0x18d6e0]
# 	(No symbol) [0x0x18e544]
# 	GetHandleVerifier [0x0x57e073+2531379]
# 	GetHandleVerifier [0x0x579372+2511666]
# 	GetHandleVerifier [0x0x349efa+220858]
# 	GetHandleVerifier [0x0x33a548+156936]
# 	GetHandleVerifier [0x0x340c7d+183357]
# 	GetHandleVerifier [0x0x32b6e8+95912]
# 	GetHandleVerifier [0x0x32b890+96336]
# 	GetHandleVerifier [0x0x31666a+9770]
# 	BaseThreadInitThunk [0x0x753d5d49+25]
# 	RtlInitializeExceptionChain [0x0x771bd09b+107]
# 	RtlGetAppContainerNamedObjectPath [0x0x771bd021+561]
# 	(No symbol) [0x0]
#
#
# 수집실패
# 25 복돈돼지국밥 수집시작
# 오류 발생: Message: entryIframe
#
#
# 수집실패
# 26 고려돼지국밥 수집시작
# 더보기 버튼이 없습니다.
# 수집성공
# 28 장전돼지국밥 수집시작
# 오류 발생: Message: entryIframe
#
#
# 수집실패
# 29 백년 돼지국밥 수집시작
# 오류 발생: Message: entryIframe
#
#
# 수집실패
# 30 한뚝배기 돼지국밥 수집시작
# 오류 발생: Message: entryIframe
#
#
# 수집실패
# 31 밀양돼지국밥&감자탕 수집시작
# 오류 발생: Message: entryIframe
#
#
# 수집실패
# 32 구월산 돼지국밥 수집시작
# 오류 발생: Message: entryIframe
#
#
# 수집실패
# 37 돼지국밥집 수집시작
# 오류 발생: Message: entryIframe
#
#
# 수집실패
# 38 장터돼지국밥 수집시작
# 오류 발생: Message: entryIframe
#
#
# 수집실패
# 46 합천돼지국밥 수집시작
# 더보기 버튼이 없습니다.
# 수집성공
# 47 당감동 돼지국밥 수집시작
# 더보기 버튼이 없습니다.
# 수집성공
# 48 수영공원돼지국밥(분점) 수집시작
# 오류 발생: Message: entryIframe
#
#
# 수집실패
# 55 정가네합천돼지국밥 수집시작
# 오류 발생: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="app-root"]/div/div/div/div[6]/div[3]/div/div[1]/div/div/div[1]/span[2]"}
#   (Session info: chrome=137.0.7151.104); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x0x323783+63299]
# 	GetHandleVerifier [0x0x3237c4+63364]
# 	(No symbol) [0x0x151113]
# 	(No symbol) [0x0x19987e]
# 	(No symbol) [0x0x199c1b]
# 	(No symbol) [0x0x1e2212]
# 	(No symbol) [0x0x1be5c4]
# 	(No symbol) [0x0x1dfa4a]
# 	(No symbol) [0x0x1be376]
# 	(No symbol) [0x0x18d6e0]
# 	(No symbol) [0x0x18e544]
# 	GetHandleVerifier [0x0x57e073+2531379]
# 	GetHandleVerifier [0x0x579372+2511666]
# 	GetHandleVerifier [0x0x349efa+220858]
# 	GetHandleVerifier [0x0x33a548+156936]
# 	GetHandleVerifier [0x0x340c7d+183357]
# 	GetHandleVerifier [0x0x32b6e8+95912]
# 	GetHandleVerifier [0x0x32b890+96336]
# 	GetHandleVerifier [0x0x31666a+9770]
# 	BaseThreadInitThunk [0x0x753d5d49+25]
# 	RtlInitializeExceptionChain [0x0x771bd09b+107]
# 	RtlGetAppContainerNamedObjectPath [0x0x771bd021+561]
# 	(No symbol) [0x0]
#
#
# 수집실패
# 58 이가네부산돼지국밥·밀면 수집시작
# 오류 발생: Message: entryIframe
#
#
# 수집실패
# 59 청도돼지국밥 수집시작
# 오류 발생: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="app-root"]/div/div/div/div[6]/div[3]/div/div[1]/div/div/div[1]/span[2]"}
#   (Session info: chrome=137.0.7151.104); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x0x323783+63299]
# 	GetHandleVerifier [0x0x3237c4+63364]
# 	(No symbol) [0x0x151113]
# 	(No symbol) [0x0x19987e]
# 	(No symbol) [0x0x199c1b]
# 	(No symbol) [0x0x1e2212]
# 	(No symbol) [0x0x1be5c4]
# 	(No symbol) [0x0x1dfa4a]
# 	(No symbol) [0x0x1be376]
# 	(No symbol) [0x0x18d6e0]
# 	(No symbol) [0x0x18e544]
# 	GetHandleVerifier [0x0x57e073+2531379]
# 	GetHandleVerifier [0x0x579372+2511666]
# 	GetHandleVerifier [0x0x349efa+220858]
# 	GetHandleVerifier [0x0x33a548+156936]
# 	GetHandleVerifier [0x0x340c7d+183357]
# 	GetHandleVerifier [0x0x32b6e8+95912]
# 	GetHandleVerifier [0x0x32b890+96336]
# 	GetHandleVerifier [0x0x31666a+9770]
# 	BaseThreadInitThunk [0x0x753d5d49+25]
# 	RtlInitializeExceptionChain [0x0x771bd09b+107]
# 	RtlGetAppContainerNamedObjectPath [0x0x771bd021+561]
# 	(No symbol) [0x0]
#
#
# 수집실패
# 64 산청 돼지국밥 수집시작
# 오류 발생: Message: entryIframe
#
#
# 수집실패
# 66 나주돼지국밥 수집시작
# 오류 발생: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="_subtab_view"]/div/a[2]"}
#   (Session info: chrome=137.0.7151.104); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x0x323783+63299]
# 	GetHandleVerifier [0x0x3237c4+63364]
# 	(No symbol) [0x0x151113]
# 	(No symbol) [0x0x19987e]
# 	(No symbol) [0x0x199c1b]
# 	(No symbol) [0x0x1e2212]
# 	(No symbol) [0x0x1be5c4]
# 	(No symbol) [0x0x1dfa4a]
# 	(No symbol) [0x0x1be376]
# 	(No symbol) [0x0x18d6e0]
# 	(No symbol) [0x0x18e544]
# 	GetHandleVerifier [0x0x57e073+2531379]
# 	GetHandleVerifier [0x0x579372+2511666]
# 	GetHandleVerifier [0x0x349efa+220858]
# 	GetHandleVerifier [0x0x33a548+156936]
# 	GetHandleVerifier [0x0x340c7d+183357]
# 	GetHandleVerifier [0x0x32b6e8+95912]
# 	GetHandleVerifier [0x0x32b890+96336]
# 	GetHandleVerifier [0x0x31666a+9770]
# 	BaseThreadInitThunk [0x0x753d5d49+25]
# 	RtlInitializeExceptionChain [0x0x771bd09b+107]
# 	RtlGetAppContainerNamedObjectPath [0x0x771bd021+561]
# 	(No symbol) [0x0]
#
#
# 수집실패
# 67 부산돼지국밥 수집시작
# 오류 발생: Message: entryIframe
#
#
# 수집실패
# 68 교통부돼지국밥 수집시작
# 오류 발생: Message: element click intercepted: Element <a href="/restaurant/13179604/review/ugc" role="tab" class="YsfhA" aria-selected="false">...</a> is not clickable at point (280, 20). Other element would receive the click: <h1 id="_header" class="bh9OH" style="opacity: 1;">...</h1>
#   (Session info: chrome=137.0.7151.104)
# Stacktrace:
# 	GetHandleVerifier [0x0x323783+63299]
# 	GetHandleVerifier [0x0x3237c4+63364]
# 	(No symbol) [0x0x151113]
# 	(No symbol) [0x0x19fbb0]
# 	(No symbol) [0x0x19df6a]
# 	(No symbol) [0x0x19bad7]
# 	(No symbol) [0x0x19ada7]
# 	(No symbol) [0x0x18f445]
# 	(No symbol) [0x0x1be57c]
# 	(No symbol) [0x0x18eed4]
# 	(No symbol) [0x0x1be7f4]
# 	(No symbol) [0x0x1dfa4a]
# 	(No symbol) [0x0x1be376]
# 	(No symbol) [0x0x18d6e0]
# 	(No symbol) [0x0x18e544]
# 	GetHandleVerifier [0x0x57e073+2531379]
# 	GetHandleVerifier [0x0x579372+2511666]
# 	GetHandleVerifier [0x0x349efa+220858]
# 	GetHandleVerifier [0x0x33a548+156936]
# 	GetHandleVerifier [0x0x340c7d+183357]
# 	GetHandleVerifier [0x0x32b6e8+95912]
# 	GetHandleVerifier [0x0x32b890+96336]
# 	GetHandleVerifier [0x0x31666a+9770]
# 	BaseThreadInitThunk [0x0x753d5d49+25]
# 	RtlInitializeExceptionChain [0x0x771bd09b+107]
# 	RtlGetAppContainerNamedObjectPath [0x0x771bd021+561]
# 	(No symbol) [0x0]
#
#
# 수집실패
# 70 부자돼지국밥 수집시작
# 오류 발생: Message: entryIframe
#
#
# 수집실패
# 71 (주)행복만들기 밀양순대돼지국밥 서면점 수집시작
# 오류 발생: Message: entryIframe
#
#
# 수집실패
# 72 수영공원돼지국밥 수집시작
# 오류 발생: Message: entryIframe
#
#
# 수집실패
# 75 제일돼지국밥 수집시작
# 오류 발생: Message: entryIframe
#
#
# 수집실패
# 83 갈맷길돼지국밥 수집시작
# 오류 발생: Message: invalid session id: session deleted as the browser has closed the connection
# from disconnected: not connected to DevTools
#   (Session info: chrome=137.0.7151.104)
# Stacktrace:
# 	GetHandleVerifier [0x0x323783+63299]
# 	GetHandleVerifier [0x0x3237c4+63364]
# 	(No symbol) [0x0x151113]
# 	(No symbol) [0x0x1408a0]
# 	(No symbol) [0x0x15e8c2]
# 	(No symbol) [0x0x1c519c]
# 	(No symbol) [0x0x1df359]
# 	(No symbol) [0x0x1be376]
# 	(No symbol) [0x0x18d6e0]
# 	(No symbol) [0x0x18e544]
# 	GetHandleVerifier [0x0x57e073+2531379]
# 	GetHandleVerifier [0x0x579372+2511666]
# 	GetHandleVerifier [0x0x349efa+220858]
# 	GetHandleVerifier [0x0x33a548+156936]
# 	GetHandleVerifier [0x0x340c7d+183357]
# 	GetHandleVerifier [0x0x32b6e8+95912]
# 	GetHandleVerifier [0x0x32b890+96336]
# 	GetHandleVerifier [0x0x31666a+9770]
# 	BaseThreadInitThunk [0x0x753d5d49+25]
# 	RtlInitializeExceptionChain [0x0x771bd09b+107]
# 	RtlGetAppContainerNamedObjectPath [0x0x771bd021+561]
# 	(No symbol) [0x0]
#
#
# 수집실패
# 84 소문난장터돼지국밥2호점 수집시작
# 오류 발생: Message: entryIframe
#
#
# 수집실패
# 85 필순할매돼지국밥 수집시작
# 오류 발생: Message: entryIframe
#
#
# 수집실패
# 86 참잘돼지국밥 수집시작
# 오류 발생: Message: entryIframe
#
#
# 수집실패
